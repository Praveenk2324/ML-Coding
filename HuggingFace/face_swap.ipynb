# %%
import torch
from diffusers import DiffusionPipeline
from diffusers.utils import load_image

pipe = DiffusionPipeline.from_pretrained("black-forest-labs/FLUX.2-klein-9B,black-forest-labs/FLUX.2-klein-4B,black-forest-labs/FLUX.2-klein-base-4B,black-forest-labs/FLUX.2-klein-base-9B,black-forest-labs/FLUX.2-klein-9b-fp8,black-forest-labs/FLUX.2-klein-4b-fp8,Qwen/Qwen-Image-Edit-2511", dtype=torch.bfloat16, device_map="cuda")
pipe.load_lora_weights("Alissonerdx/BFS-Best-Face-Swap")

prompt = "Turn this cat into a dog"
input_image = load_image("https://huggingface.co/datasets/huggingface/documentation-images/resolve/main/diffusers/cat.png")

image = pipe(image=input_image, prompt=prompt).images[0]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[1], line 5
#       1 import torch
#       2 from diffusers import DiffusionPipeline
#       3 from diffusers.utils import load_image
#       4
# ----> 5 pipe = DiffusionPipeline.from_pretrained("black-forest-labs/FLUX.2-klein-9B,black-forest-labs/FLUX.2-klein-4B,black-forest-labs/FLUX.2-klein-base-4B,black-forest-labs/FLUX.2-klein-base-9B,black-forest-labs/FLUX.2-klein-9b-fp8,black-forest-labs/FLUX.2-klein-4b-fp8,Qwen/Qwen-Image-Edit-2511", dtype=torch.bfloat16, device_map="cuda")
#       6 pipe.load_lora_weights("Alissonerdx/BFS-Best-Face-Swap")
#       7
#       8 prompt = "Turn this cat into a dog"
#
# File c:\AnacondaEnvs\aiml_env\Lib\site-packages\huggingface_hub\utils\_validators.py:88, in validate_hf_hub_args.<locals>._inner_fn(*args, **kwargs)
#      84         validate_repo_id(arg_value)
#      86 kwargs = smoothly_deprecate_legacy_arguments(fn_name=fn.__name__, kwargs=kwargs)
# ---> 88 return fn(*args, **kwargs)
#
# File c:\AnacondaEnvs\aiml_env\Lib\site-packages\diffusers\pipelines\pipeline_utils.py:855, in DiffusionPipeline.from_pretrained(cls, pretrained_model_name_or_path, **kwargs)
#     853 if not os.path.isdir(pretrained_model_name_or_path):
#     854     if pretrained_model_name_or_path.count("/") > 1:
# --> 855         raise ValueError(
#     856             f'The provided pretrained_model_name_or_path "{pretrained_model_name_or_path}"'
#     857             " is neither a valid local path nor a valid repo id. Please check the parameter."
#     858         )
#     859     cached_folder = cls.download(
#     860         pretrained_model_name_or_path,
#     861         cache_dir=cache_dir,
#    (...)    876         **kwargs,
#     877     )
#     878 else:
#
# ValueError: The provided pretrained_model_name_or_path "black-forest-labs/FLUX.2-klein-9B,black-forest-labs/FLUX.2-klein-4B,black-forest-labs/FLUX.2-klein-base-4B,black-forest-labs/FLUX.2-klein-base-9B,black-forest-labs/FLUX.2-klein-9b-fp8,black-forest-labs/FLUX.2-klein-4b-fp8,Qwen/Qwen-Image-Edit-2511" is neither a valid local path nor a valid repo id. Please check the parameter.
